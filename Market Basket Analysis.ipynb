# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

pd.set_option('display.max_rows', None)

# %% [markdown]
# Source of the code: https://pbpython.com/market-basket-analysis.html

# %% [markdown]
# Association rules are normally written like this: {Diapers} -> {Beer} which means that there is a strong relationship between customers that purchased diapers and also purchased beer in the same transaction.
#
# The {Diaper} is the antecedent and the {Beer} is the consequent. Both antecedents and consequents can have multiple items. In other words, {Diaper, Gum} -> {Beer, Chips} is a valid rule.
#
# Support is the relative frequency that the rules show up. In many instances, you may want to look for high support in order to make sure it is a useful relationship. However, there may be instances where a low support is useful if you are trying to find “hidden” relationships.
#
# Confidence is a measure of the reliability of the rule. A confidence of .5 in the above example would mean that in 50% of the cases where Diaper and Gum were purchased, the purchase also included Beer and Chips. For product recommendation, a 50% confidence may be perfectly acceptable but in a medical situation, this level may not be high enough.
#
# Lift is the ratio of the observed support to that expected if the two rules were independent (see wikipedia). The basic rule of thumb is that a lift value close to 1 means the rules were completely independent. Lift values > 1 are generally more “interesting” and could be indicative of a useful rule pattern.

# %%
# Read data set 

df = pd.read_excel("df_retail.xlsx")

# %%
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom

# %% [markdown]
# ##### France

# %%
basket = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                  0.0                 0.0
# 536852                                  0.0                 0.0
# 536974                                  0.0                 0.0
# 537065                                  0.0                 0.0
# 537463                                  0.0                 0.0
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                                0.0                       0.0
# 536852                                0.0                       0.0
# 536974                                0.0                       0.0
# 537065                                0.0                       0.0
# 537463                                0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536370                                   24.0                      0.0
# 536852                                    0.0                      0.0
# 536974                                    0.0                      0.0
# 537065                                    0.0                      0.0
# 537463                                    0.0                      0.0
#
# Description   TRELLIS COAT RACK  10 COLOUR SPACEBOY PEN  \
# InvoiceNo
# 536370                      0.0                     0.0
# 536852                      0.0                     0.0
# 536974                      0.0                     0.0
# 537065                      0.0                     0.0
# 537463                      0.0                     0.0
#
# Description  12 COLOURED PARTY BALLOONS  12 EGG HOUSE PAINTED WOOD  ...  \
# InvoiceNo                                                           ...
# 536370                              0.0                        0.0  ...
# 536852                              0.0                        0.0  ...
# 536974                              0.0                        0.0  ...
# 537065                              0.0                        0.0  ...
# 537463                              0.0                        0.0  ...
#
# Description  WRAP SUKI AND FRIENDS  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo
# 536370                         0.0                          0.0
# 536852                         0.0                          0.0
# 536974                         0.0                          0.0
# 537065                         0.0                          0.0
# 537463                         0.0                          0.0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
#
# Description  ZINC  STAR T-LIGHT HOLDER   ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536370                              0.0                        0.0
# 536852                              0.0                        0.0
# 536974                              0.0                        0.0
# 537065                              0.0                        0.0
# 537463                              0.0                        0.0
#
# Description  ZINC HERB GARDEN CONTAINER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536370                              0.0                          0.0
# 536852                              0.0                          0.0
# 536974                              0.0                          0.0
# 537065                              0.0                          0.0
# 537463                              0.0                          0.0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
#
# [5 rows x 1544 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules
# Out:
#                                           antecedents  \
# 0                         (ALARM CLOCK BAKELIKE PINK)
# 1                        (ALARM CLOCK BAKELIKE GREEN)
# 2                         (ALARM CLOCK BAKELIKE RED )
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 4                         (ALARM CLOCK BAKELIKE RED )
# 5                         (ALARM CLOCK BAKELIKE PINK)
# 6                               (SPACEBOY LUNCH BOX )
# 7                              (DOLLY GIRL LUNCH BOX)
# 8                    (PLASTERS IN TIN CIRCUS PARADE )
# 9                          (PLASTERS IN TIN SPACEBOY)
# 10                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 11                   (PLASTERS IN TIN CIRCUS PARADE )
# 12                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 13                         (PLASTERS IN TIN SPACEBOY)
# 14                      (SET/6 RED SPOTTY PAPER CUPS)
# 15              (SET/20 RED RETROSPOT PAPER NAPKINS )
# 16              (SET/20 RED RETROSPOT PAPER NAPKINS )
# 17                    (SET/6 RED SPOTTY PAPER PLATES)
# 18                      (SET/6 RED SPOTTY PAPER CUPS)
# 19                    (SET/6 RED SPOTTY PAPER PLATES)
# 20  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 21  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 22  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 23                      (SET/6 RED SPOTTY PAPER CUPS)
# 24              (SET/20 RED RETROSPOT PAPER NAPKINS )
# 25                    (SET/6 RED SPOTTY PAPER PLATES)
#
#                                           consequents  antecedent support  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)            0.102828
# 1                         (ALARM CLOCK BAKELIKE PINK)            0.097686
# 2                        (ALARM CLOCK BAKELIKE GREEN)            0.095116
# 3                         (ALARM CLOCK BAKELIKE RED )            0.097686
# 4                         (ALARM CLOCK BAKELIKE PINK)            0.095116
# 5                         (ALARM CLOCK BAKELIKE RED )            0.102828
# 6                              (DOLLY GIRL LUNCH BOX)            0.125964
# 7                               (SPACEBOY LUNCH BOX )            0.100257
# 8                          (PLASTERS IN TIN SPACEBOY)            0.169666
# 9                    (PLASTERS IN TIN CIRCUS PARADE )            0.136247
# 10                   (PLASTERS IN TIN CIRCUS PARADE )            0.172237
# 11                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.169666
# 12                         (PLASTERS IN TIN SPACEBOY)            0.172237
# 13                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.136247
# 14              (SET/20 RED RETROSPOT PAPER NAPKINS )            0.138817
# 15                      (SET/6 RED SPOTTY PAPER CUPS)            0.133676
# 16                    (SET/6 RED SPOTTY PAPER PLATES)            0.133676
# 17              (SET/20 RED RETROSPOT PAPER NAPKINS )            0.128535
# 18                    (SET/6 RED SPOTTY PAPER PLATES)            0.138817
# 19                      (SET/6 RED SPOTTY PAPER CUPS)            0.128535
# 20                    (SET/6 RED SPOTTY PAPER PLATES)            0.102828
# 21              (SET/20 RED RETROSPOT PAPER NAPKINS )            0.123393
# 22                      (SET/6 RED SPOTTY PAPER CUPS)            0.102828
# 23  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...            0.138817
# 24  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...            0.133676
# 25  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...            0.128535
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.097686  0.074550    0.725000  7.421711  0.064505    3.281140
# 1             0.102828  0.074550    0.763158  7.421711  0.064505    3.788061
# 2             0.097686  0.079692    0.837838  8.576814  0.070400    5.564267
# 3             0.095116  0.079692    0.815789  8.576814  0.070400    4.912229
# 4             0.102828  0.074550    0.783784  7.622297  0.064770    4.149422
# 5             0.095116  0.074550    0.725000  7.622297  0.064770    3.290488
# 6             0.100257  0.071979    0.571429  5.699634  0.059351    2.099400
# 7             0.125964  0.071979    0.717949  5.699634  0.059351    3.098855
# 8             0.136247  0.089974    0.530303  3.892224  0.066858    1.838958
# 9             0.169666  0.089974    0.660377  3.892224  0.066858    2.444873
# 10            0.169666  0.102828    0.597015  3.518770  0.073605    2.060459
# 11            0.172237  0.102828    0.606061  3.518770  0.073605    2.101246
# 12            0.136247  0.105398    0.611940  4.491411  0.081932    2.225826
# 13            0.172237  0.105398    0.773585  4.491411  0.081932    3.655955
# 14            0.133676  0.102828    0.740741  5.541311  0.084271    3.341535
# 15            0.138817  0.102828    0.769231  5.541311  0.084271    3.731791
# 16            0.128535  0.102828    0.769231  5.984615  0.085646    3.776350
# 17            0.133676  0.102828    0.800000  5.984615  0.085646    4.331620
# 18            0.128535  0.123393    0.888889  6.915556  0.105550    7.843188
# 19            0.138817  0.123393    0.960000  6.915556  0.105550   21.529563
# 20            0.128535  0.100257    0.975000  7.585500  0.087040   34.858612
# 21            0.133676  0.100257    0.812500  6.078125  0.083762    4.620394
# 22            0.138817  0.100257    0.975000  7.023611  0.085983   34.447301
# 23            0.102828  0.100257    0.722222  7.023611  0.085983    3.229820
# 24            0.123393  0.100257    0.750000  6.078125  0.083762    3.506427
# 25            0.102828  0.100257    0.780000  7.585500  0.087040    4.078056

# %% [markdown]
# Interpretation row 1:

# %% [markdown]
# A customer is 7 times more likely to buy a ALARM CLOCK BAKELIKE GREEN than an average customer (lift) if he buys ALARM CLOCK BAKELIKE PINK. This rule is "true" in 72% of the cases (confidence). This insight might be used for a recommendation: Recommend ALARM CLOCK BAKELIKE GREEN for customer who choose/ bought the green version.

# %%
#or see row 14:

#SET/6 RED SPOTTY PAPER CUPS) 	(SET/20 RED RETROSPOT PAPER NAPKINS )

# %%
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8) ]
# Out:
#                                           antecedents  \
# 2                         (ALARM CLOCK BAKELIKE RED )
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 18                      (SET/6 RED SPOTTY PAPER CUPS)
# 19                    (SET/6 RED SPOTTY PAPER PLATES)
# 20  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 21  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 22  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
#
#                               consequents  antecedent support  \
# 2            (ALARM CLOCK BAKELIKE GREEN)            0.095116
# 3             (ALARM CLOCK BAKELIKE RED )            0.097686
# 18        (SET/6 RED SPOTTY PAPER PLATES)            0.138817
# 19          (SET/6 RED SPOTTY PAPER CUPS)            0.128535
# 20        (SET/6 RED SPOTTY PAPER PLATES)            0.102828
# 21  (SET/20 RED RETROSPOT PAPER NAPKINS )            0.123393
# 22          (SET/6 RED SPOTTY PAPER CUPS)            0.102828
#
#     consequent support   support  confidence      lift  leverage  conviction
# 2             0.097686  0.079692    0.837838  8.576814  0.070400    5.564267
# 3             0.095116  0.079692    0.815789  8.576814  0.070400    4.912229
# 18            0.128535  0.123393    0.888889  6.915556  0.105550    7.843188
# 19            0.138817  0.123393    0.960000  6.915556  0.105550   21.529563
# 20            0.128535  0.100257    0.975000  7.585500  0.087040   34.858612
# 21            0.133676  0.100257    0.812500  6.078125  0.083762    4.620394
# 22            0.138817  0.100257    0.975000  7.023611  0.085983   34.447301

# %%
basket['ALARM CLOCK BAKELIKE GREEN'].sum()
# Out:
# 340.0

# %% [markdown]
# ##### United Kingdom

# %%
basket2 = (df[df['Country'] =="United Kingdom"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets2 = basket2.applymap(encode_units)
basket_sets2.drop('POSTAGE', inplace=True, axis=1)

# %%
frequent_itemsets2 = apriori(basket_sets2, min_support=0.02, use_colnames=True)

# %%
rules2 = association_rules(frequent_itemsets2, metric="lift", min_threshold=1)
rules2
# Out:
#                                           antecedents  \
# 0                         (ALARM CLOCK BAKELIKE RED )
# 1                        (ALARM CLOCK BAKELIKE GREEN)
# 2                (GARDENERS KNEELING PAD CUP OF TEA )
# 3                 (GARDENERS KNEELING PAD KEEP CALM )
# 4                    (PINK REGENCY TEACUP AND SAUCER)
# 5                   (GREEN REGENCY TEACUP AND SAUCER)
# 6                  (ROSES REGENCY TEACUP AND SAUCER )
# 7                   (GREEN REGENCY TEACUP AND SAUCER)
# 8                             (HEART OF WICKER SMALL)
# 9                             (HEART OF WICKER LARGE)
# 10                          (JUMBO BAG RED RETROSPOT)
# 11                   (JUMBO  BAG BAROQUE BLACK WHITE)
# 12                          (JUMBO BAG PINK POLKADOT)
# 13                          (JUMBO BAG RED RETROSPOT)
# 14                          (JUMBO BAG RED RETROSPOT)
# 15                             (JUMBO BAG STRAWBERRY)
# 16                (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 17                          (JUMBO BAG RED RETROSPOT)
# 18                           (JUMBO STORAGE BAG SUKI)
# 19                          (JUMBO BAG RED RETROSPOT)
# 20                          (LUNCH BAG RED RETROSPOT)
# 21                          (JUMBO BAG RED RETROSPOT)
# 22                              (LUNCH BAG CARS BLUE)
# 23                          (LUNCH BAG  BLACK SKULL.)
# 24                          (LUNCH BAG  BLACK SKULL.)
# 25                          (LUNCH BAG PINK POLKADOT)
# 26                          (LUNCH BAG RED RETROSPOT)
# 27                          (LUNCH BAG  BLACK SKULL.)
# 28                       (LUNCH BAG SPACEBOY DESIGN )
# 29                          (LUNCH BAG  BLACK SKULL.)
# 30                           (LUNCH BAG SUKI DESIGN )
# 31                          (LUNCH BAG  BLACK SKULL.)
# 32                          (LUNCH BAG RED RETROSPOT)
# 33                           (LUNCH BAG APPLE DESIGN)
# 34                              (LUNCH BAG CARS BLUE)
# 35                          (LUNCH BAG PINK POLKADOT)
# 36                              (LUNCH BAG CARS BLUE)
# 37                          (LUNCH BAG RED RETROSPOT)
# 38                       (LUNCH BAG SPACEBOY DESIGN )
# 39                              (LUNCH BAG CARS BLUE)
# 40                              (LUNCH BAG CARS BLUE)
# 41                           (LUNCH BAG SUKI DESIGN )
# 42                          (LUNCH BAG RED RETROSPOT)
# 43                          (LUNCH BAG PINK POLKADOT)
# 44                       (LUNCH BAG SPACEBOY DESIGN )
# 45                          (LUNCH BAG PINK POLKADOT)
# 46                           (LUNCH BAG SUKI DESIGN )
# 47                          (LUNCH BAG PINK POLKADOT)
# 48                       (LUNCH BAG SPACEBOY DESIGN )
# 49                          (LUNCH BAG RED RETROSPOT)
# 50                           (LUNCH BAG SUKI DESIGN )
# 51                          (LUNCH BAG RED RETROSPOT)
# 52                          (LUNCH BAG RED RETROSPOT)
# 53                               (LUNCH BAG WOODLAND)
# 54                       (LUNCH BAG SPACEBOY DESIGN )
# 55                           (LUNCH BAG SUKI DESIGN )
# 56                       (LUNCH BAG SPACEBOY DESIGN )
# 57                               (LUNCH BAG WOODLAND)
# 58                (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 59                  (PAPER CHAIN KIT 50'S CHRISTMAS )
# 60                                    (PARTY BUNTING)
# 61                                   (SPOTTY BUNTING)
# 62                 (ROSES REGENCY TEACUP AND SAUCER )
# 63                   (PINK REGENCY TEACUP AND SAUCER)
# 64                 (RED HANGING HEART T-LIGHT HOLDER)
# 65               (WHITE HANGING HEART T-LIGHT HOLDER)
# 66                         (REGENCY CAKESTAND 3 TIER)
# 67                 (ROSES REGENCY TEACUP AND SAUCER )
# 68                      (WOODEN FRAME ANTIQUE WHITE )
# 69                (WOODEN PICTURE FRAME WHITE FINISH)
# 70  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 71  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...
# 72  (PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...
# 73                 (ROSES REGENCY TEACUP AND SAUCER )
# 74                   (PINK REGENCY TEACUP AND SAUCER)
# 75                  (GREEN REGENCY TEACUP AND SAUCER)
#
#                                           consequents  antecedent support  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)            0.045536
# 1                         (ALARM CLOCK BAKELIKE RED )            0.041451
# 2                 (GARDENERS KNEELING PAD KEEP CALM )            0.037667
# 3                (GARDENERS KNEELING PAD CUP OF TEA )            0.044575
# 4                   (GREEN REGENCY TEACUP AND SAUCER)            0.029617
# 5                    (PINK REGENCY TEACUP AND SAUCER)            0.036766
# 6                   (GREEN REGENCY TEACUP AND SAUCER)            0.040731
# 7                  (ROSES REGENCY TEACUP AND SAUCER )            0.036766
# 8                             (HEART OF WICKER LARGE)            0.055749
# 9                             (HEART OF WICKER SMALL)            0.047519
# 10                   (JUMBO  BAG BAROQUE BLACK WHITE)            0.086928
# 11                          (JUMBO BAG RED RETROSPOT)            0.037607
# 12                          (JUMBO BAG RED RETROSPOT)            0.048780
# 13                          (JUMBO BAG PINK POLKADOT)            0.086928
# 14                             (JUMBO BAG STRAWBERRY)            0.086928
# 15                          (JUMBO BAG RED RETROSPOT)            0.037366
# 16                          (JUMBO BAG RED RETROSPOT)            0.044996
# 17                (JUMBO SHOPPER VINTAGE RED PAISLEY)            0.086928
# 18                          (JUMBO BAG RED RETROSPOT)            0.043254
# 19                           (JUMBO STORAGE BAG SUKI)            0.086928
# 20                          (JUMBO BAG RED RETROSPOT)            0.067283
# 21                          (LUNCH BAG RED RETROSPOT)            0.086928
# 22                          (LUNCH BAG  BLACK SKULL.)            0.052986
# 23                              (LUNCH BAG CARS BLUE)            0.059834
# 24                          (LUNCH BAG PINK POLKADOT)            0.059834
# 25                          (LUNCH BAG  BLACK SKULL.)            0.050943
# 26                          (LUNCH BAG  BLACK SKULL.)            0.067283
# 27                          (LUNCH BAG RED RETROSPOT)            0.059834
# 28                          (LUNCH BAG  BLACK SKULL.)            0.052445
# 29                       (LUNCH BAG SPACEBOY DESIGN )            0.059834
# 30                          (LUNCH BAG  BLACK SKULL.)            0.050222
# 31                           (LUNCH BAG SUKI DESIGN )            0.059834
# 32                           (LUNCH BAG APPLE DESIGN)            0.067283
# 33                          (LUNCH BAG RED RETROSPOT)            0.044816
# 34                          (LUNCH BAG PINK POLKADOT)            0.052986
# 35                              (LUNCH BAG CARS BLUE)            0.050943
# 36                          (LUNCH BAG RED RETROSPOT)            0.052986
# 37                              (LUNCH BAG CARS BLUE)            0.067283
# 38                              (LUNCH BAG CARS BLUE)            0.052445
# 39                       (LUNCH BAG SPACEBOY DESIGN )            0.052986
# 40                           (LUNCH BAG SUKI DESIGN )            0.052986
# 41                              (LUNCH BAG CARS BLUE)            0.050222
# 42                          (LUNCH BAG PINK POLKADOT)            0.067283
# 43                          (LUNCH BAG RED RETROSPOT)            0.050943
# 44                          (LUNCH BAG PINK POLKADOT)            0.052445
# 45                       (LUNCH BAG SPACEBOY DESIGN )            0.050943
# 46                          (LUNCH BAG PINK POLKADOT)            0.050222
# 47                           (LUNCH BAG SUKI DESIGN )            0.050943
# 48                          (LUNCH BAG RED RETROSPOT)            0.052445
# 49                       (LUNCH BAG SPACEBOY DESIGN )            0.067283
# 50                          (LUNCH BAG RED RETROSPOT)            0.050222
# 51                           (LUNCH BAG SUKI DESIGN )            0.067283
# 52                               (LUNCH BAG WOODLAND)            0.067283
# 53                          (LUNCH BAG RED RETROSPOT)            0.040490
# 54                           (LUNCH BAG SUKI DESIGN )            0.052445
# 55                       (LUNCH BAG SPACEBOY DESIGN )            0.050222
# 56                               (LUNCH BAG WOODLAND)            0.052445
# 57                       (LUNCH BAG SPACEBOY DESIGN )            0.040490
# 58                  (PAPER CHAIN KIT 50'S CHRISTMAS )            0.040670
# 59                (PAPER CHAIN KIT VINTAGE CHRISTMAS)            0.056770
# 60                                   (SPOTTY BUNTING)            0.077496
# 61                                    (PARTY BUNTING)            0.054548
# 62                   (PINK REGENCY TEACUP AND SAUCER)            0.040731
# 63                 (ROSES REGENCY TEACUP AND SAUCER )            0.029617
# 64               (WHITE HANGING HEART T-LIGHT HOLDER)            0.038568
# 65                 (RED HANGING HEART T-LIGHT HOLDER)            0.113180
# 66                 (ROSES REGENCY TEACUP AND SAUCER )            0.084705
# 67                         (REGENCY CAKESTAND 3 TIER)            0.040731
# 68                (WOODEN PICTURE FRAME WHITE FINISH)            0.047098
# 69                      (WOODEN FRAME ANTIQUE WHITE )            0.051304
# 70                  (GREEN REGENCY TEACUP AND SAUCER)            0.023009
# 71                   (PINK REGENCY TEACUP AND SAUCER)            0.028595
# 72                 (ROSES REGENCY TEACUP AND SAUCER )            0.024270
# 73  (PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...            0.040731
# 74  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...            0.029617
# 75  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...            0.036766
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.041451  0.027274    0.598945  14.449321  0.025386    2.390065
# 1             0.045536  0.027274    0.657971  14.449321  0.025386    2.790593
# 2             0.044575  0.027514    0.730463  16.387169  0.025835    3.544682
# 3             0.037667  0.027514    0.617251  16.387169  0.025835    2.514265
# 4             0.036766  0.024270    0.819473  22.289120  0.023181    5.335669
# 5             0.029617  0.024270    0.660131  22.289120  0.023181    2.855166
# 6             0.036766  0.028595    0.702065  19.095706  0.027098    3.233034
# 7             0.040731  0.028595    0.777778  19.095706  0.027098    4.316713
# 8             0.047519  0.023910    0.428879   9.025442  0.021261    1.667740
# 9             0.055749  0.023910    0.503161   9.025442  0.021261    1.900515
# 10            0.037607  0.020846    0.239806   6.376708  0.017577    1.265985
# 11            0.086928  0.020846    0.554313   6.376708  0.017577    2.048685
# 12            0.086928  0.030398    0.623153   7.168625  0.026157    2.422924
# 13            0.048780  0.030398    0.349689   7.168625  0.026157    1.462715
# 14            0.037366  0.023729    0.272979   7.305468  0.020481    1.324079
# 15            0.086928  0.023729    0.635048   7.305468  0.020481    2.501898
# 16            0.086928  0.022408    0.497997   5.728862  0.018496    1.818859
# 17            0.044996  0.022408    0.257775   5.728862  0.018496    1.286677
# 18            0.086928  0.024510    0.566667   6.518821  0.020750    2.107090
# 19            0.043254  0.024510    0.281963   6.518821  0.020750    1.332447
# 20            0.086928  0.022648    0.336607   3.872262  0.016799    1.376367
# 21            0.067283  0.022648    0.260539   3.872262  0.016799    1.261347
# 22            0.059834  0.024150    0.455782   7.617422  0.020980    1.727555
# 23            0.052986  0.024150    0.403614   7.617422  0.020980    1.587923
# 24            0.050943  0.026553    0.443775   8.711180  0.023505    1.706247
# 25            0.059834  0.026553    0.521226   8.711180  0.023505    1.963696
# 26            0.059834  0.029076    0.432143   7.222339  0.025050    1.655638
# 27            0.067283  0.029076    0.485944   7.222339  0.025050    1.814425
# 28            0.059834  0.023369    0.445590   7.447078  0.020231    1.695795
# 29            0.052445  0.023369    0.390562   7.447078  0.020231    1.554802
# 30            0.059834  0.023609    0.470096   7.856639  0.020604    1.774218
# 31            0.050222  0.023609    0.394578   7.856639  0.020604    1.568787
# 32            0.044816  0.020005    0.297321   6.634333  0.016989    1.359348
# 33            0.067283  0.020005    0.446381   6.634333  0.016989    1.684762
# 34            0.050943  0.023789    0.448980   8.813342  0.021090    1.722362
# 35            0.052986  0.023789    0.466981   8.813342  0.021090    1.776699
# 36            0.067283  0.024811    0.468254   6.959425  0.021246    1.754064
# 37            0.052986  0.024811    0.368750   6.959425  0.021246    1.500221
# 38            0.052986  0.021807    0.415808   7.847543  0.019028    1.621066
# 39            0.052445  0.021807    0.411565   7.847543  0.019028    1.610296
# 40            0.050222  0.021807    0.411565   8.194862  0.019146    1.614073
# 41            0.052986  0.021807    0.434211   8.194862  0.019146    1.673793
# 42            0.050943  0.028295    0.420536   8.254997  0.024867    1.637818
# 43            0.067283  0.028295    0.555425   8.254997  0.024867    2.097994
# 44            0.050943  0.020065    0.382589   7.510109  0.017393    1.537155
# 45            0.052445  0.020065    0.393868   7.510109  0.017393    1.563281
# 46            0.050943  0.020005    0.398325   7.819014  0.017446    1.577359
# 47            0.050222  0.020005    0.392689   7.819014  0.017446    1.563906
# 48            0.067283  0.024631    0.469645   6.980097  0.021102    1.758664
# 49            0.052445  0.024631    0.366071   6.980097  0.021102    1.494735
# 50            0.067283  0.024631    0.490431   7.289025  0.021251    1.830402
# 51            0.050222  0.024631    0.366071   7.289025  0.021251    1.498241
# 52            0.040490  0.021867    0.325000   8.026632  0.019143    1.421496
# 53            0.067283  0.021867    0.540059   8.026632  0.019143    2.027906
# 54            0.050222  0.020906    0.398625   7.937224  0.018272    1.579345
# 55            0.052445  0.020906    0.416268   7.937224  0.018272    1.623270
# 56            0.040490  0.020786    0.396334   9.788403  0.018662    1.589473
# 57            0.052445  0.020786    0.513353   9.788403  0.018662    1.947110
# 58            0.056770  0.026253    0.645495  11.370272  0.023944    2.660694
# 59            0.040670  0.026253    0.462434  11.370272  0.023944    1.784580
# 60            0.054548  0.021567    0.278295   5.101863  0.017340    1.310025
# 61            0.077496  0.021567    0.395374   5.101863  0.017340    1.525744
# 62            0.029617  0.023009    0.564897  19.073573  0.021802    2.230237
# 63            0.040731  0.023009    0.776876  19.073573  0.021802    4.299271
# 64            0.113180  0.025712    0.666667   5.890304  0.021347    2.660459
# 65            0.038568  0.025712    0.227176   5.890304  0.021347    1.244051
# 66            0.040731  0.021146    0.249645   6.129199  0.017696    1.278422
# 67            0.084705  0.021146    0.519174   6.129199  0.017696    1.903589
# 68            0.051304  0.027514    0.584184  11.386793  0.025098    2.281527
# 69            0.047098  0.027514    0.536300  11.386793  0.025098    2.054995
# 70            0.036766  0.020485    0.890339  24.216650  0.019639    8.783780
# 71            0.029617  0.020485    0.716387  24.188581  0.019638    3.421500
# 72            0.040731  0.020485    0.844059  20.723028  0.019497    6.151506
# 73            0.024270  0.020485    0.502950  20.723028  0.019497    1.963041
# 74            0.028595  0.020485    0.691684  24.188581  0.019638    3.150674
# 75            0.023009  0.020485    0.557190  24.216650  0.019639    2.206342

# %%
rules2[ (rules2['lift'] >= 6) &
       (rules2['confidence'] >= 0.7) ]
# Out:
#                                           antecedents  \
# 2                (GARDENERS KNEELING PAD CUP OF TEA )
# 4                    (PINK REGENCY TEACUP AND SAUCER)
# 6                  (ROSES REGENCY TEACUP AND SAUCER )
# 7                   (GREEN REGENCY TEACUP AND SAUCER)
# 63                   (PINK REGENCY TEACUP AND SAUCER)
# 70  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 71  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...
# 72  (PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...
#
#                             consequents  antecedent support  \
# 2   (GARDENERS KNEELING PAD KEEP CALM )            0.037667
# 4     (GREEN REGENCY TEACUP AND SAUCER)            0.029617
# 6     (GREEN REGENCY TEACUP AND SAUCER)            0.040731
# 7    (ROSES REGENCY TEACUP AND SAUCER )            0.036766
# 63   (ROSES REGENCY TEACUP AND SAUCER )            0.029617
# 70    (GREEN REGENCY TEACUP AND SAUCER)            0.023009
# 71     (PINK REGENCY TEACUP AND SAUCER)            0.028595
# 72   (ROSES REGENCY TEACUP AND SAUCER )            0.024270
#
#     consequent support   support  confidence       lift  leverage  conviction
# 2             0.044575  0.027514    0.730463  16.387169  0.025835    3.544682
# 4             0.036766  0.024270    0.819473  22.289120  0.023181    5.335669
# 6             0.036766  0.028595    0.702065  19.095706  0.027098    3.233034
# 7             0.040731  0.028595    0.777778  19.095706  0.027098    4.316713
# 63            0.040731  0.023009    0.776876  19.073573  0.021802    4.299271
# 70            0.036766  0.020485    0.890339  24.216650  0.019639    8.783780
# 71            0.029617  0.020485    0.716387  24.188581  0.019638    3.421500
# 72            0.040731  0.020485    0.844059  20.723028  0.019497    6.151506

# %% [markdown]
# ##### Germany

# %%
basket3 = (df[df['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets3 = basket3.applymap(encode_units)
basket_sets3.drop('POSTAGE', inplace=True, axis=1)

# %%
frequent_itemsets3 = apriori(basket_sets3, min_support=0.05, use_colnames=True)

# %%
rules3 = association_rules(frequent_itemsets3, metric="lift", min_threshold=1)
rules3
# Out:
#                               antecedents  \
# 0        (PLASTERS IN TIN CIRCUS PARADE )
# 1      (PLASTERS IN TIN WOODLAND ANIMALS)
# 2        (PLASTERS IN TIN CIRCUS PARADE )
# 3    (ROUND SNACK BOXES SET OF 4 FRUITS )
# 4   (ROUND SNACK BOXES SET OF4 WOODLAND )
# 5        (PLASTERS IN TIN CIRCUS PARADE )
# 6      (PLASTERS IN TIN WOODLAND ANIMALS)
# 7              (PLASTERS IN TIN SPACEBOY)
# 8   (ROUND SNACK BOXES SET OF4 WOODLAND )
# 9      (PLASTERS IN TIN WOODLAND ANIMALS)
# 10               (WOODLAND CHARLOTTE BAG)
# 11          (RED RETROSPOT CHARLOTTE BAG)
# 12  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 13   (ROUND SNACK BOXES SET OF 4 FRUITS )
# 14  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 15                  (SPACEBOY LUNCH BOX )
# 16  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 17               (WOODLAND CHARLOTTE BAG)
#
#                               consequents  antecedent support  \
# 0      (PLASTERS IN TIN WOODLAND ANIMALS)            0.115974
# 1        (PLASTERS IN TIN CIRCUS PARADE )            0.137856
# 2    (ROUND SNACK BOXES SET OF 4 FRUITS )            0.115974
# 3        (PLASTERS IN TIN CIRCUS PARADE )            0.157549
# 4        (PLASTERS IN TIN CIRCUS PARADE )            0.245077
# 5   (ROUND SNACK BOXES SET OF4 WOODLAND )            0.115974
# 6              (PLASTERS IN TIN SPACEBOY)            0.137856
# 7      (PLASTERS IN TIN WOODLAND ANIMALS)            0.107221
# 8      (PLASTERS IN TIN WOODLAND ANIMALS)            0.245077
# 9   (ROUND SNACK BOXES SET OF4 WOODLAND )            0.137856
# 10          (RED RETROSPOT CHARLOTTE BAG)            0.126915
# 11               (WOODLAND CHARLOTTE BAG)            0.070022
# 12   (ROUND SNACK BOXES SET OF 4 FRUITS )            0.245077
# 13  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.157549
# 14                  (SPACEBOY LUNCH BOX )            0.245077
# 15  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.102845
# 16               (WOODLAND CHARLOTTE BAG)            0.245077
# 17  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.126915
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.137856  0.067834    0.584906  4.242887  0.051846    2.076984
# 1             0.115974  0.067834    0.492063  4.242887  0.051846    1.740427
# 2             0.157549  0.050328    0.433962  2.754455  0.032057    1.488330
# 3             0.115974  0.050328    0.319444  2.754455  0.032057    1.298977
# 4             0.115974  0.056893    0.232143  2.001685  0.028470    1.151290
# 5             0.245077  0.056893    0.490566  2.001685  0.028470    1.481887
# 6             0.107221  0.061269    0.444444  4.145125  0.046488    1.607002
# 7             0.137856  0.061269    0.571429  4.145125  0.046488    2.011670
# 8             0.137856  0.074398    0.303571  2.202098  0.040613    1.237951
# 9             0.245077  0.074398    0.539683  2.202098  0.040613    1.640006
# 10            0.070022  0.059081    0.465517  6.648168  0.050194    1.739959
# 11            0.126915  0.059081    0.843750  6.648168  0.050194    5.587746
# 12            0.157549  0.131291    0.535714  3.400298  0.092679    1.814509
# 13            0.245077  0.131291    0.833333  3.400298  0.092679    4.529540
# 14            0.102845  0.070022    0.285714  2.778116  0.044817    1.256018
# 15            0.245077  0.070022    0.680851  2.778116  0.044817    2.365427
# 16            0.126915  0.063457    0.258929  2.040179  0.032354    1.178139
# 17            0.245077  0.063457    0.500000  2.040179  0.032354    1.509847

# %%
rules3[ (rules3['lift'] >= 6) &
       (rules3['confidence'] >= 0.7) ]
# Out:
#                                           antecedents  \
# 2                (GARDENERS KNEELING PAD CUP OF TEA )
# 4                    (PINK REGENCY TEACUP AND SAUCER)
# 6                  (ROSES REGENCY TEACUP AND SAUCER )
# 7                   (GREEN REGENCY TEACUP AND SAUCER)
# 63                   (PINK REGENCY TEACUP AND SAUCER)
# 70  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 71  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...
# 72  (PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...
#
#                             consequents  antecedent support  \
# 2   (GARDENERS KNEELING PAD KEEP CALM )            0.037667
# 4     (GREEN REGENCY TEACUP AND SAUCER)            0.029617
# 6     (GREEN REGENCY TEACUP AND SAUCER)            0.040731
# 7    (ROSES REGENCY TEACUP AND SAUCER )            0.036766
# 63   (ROSES REGENCY TEACUP AND SAUCER )            0.029617
# 70    (GREEN REGENCY TEACUP AND SAUCER)            0.023009
# 71     (PINK REGENCY TEACUP AND SAUCER)            0.028595
# 72   (ROSES REGENCY TEACUP AND SAUCER )            0.024270
#
#     consequent support   support  confidence       lift  leverage  conviction
# 2             0.044575  0.027514    0.730463  16.387169  0.025835    3.544682
# 4             0.036766  0.024270    0.819473  22.289120  0.023181    5.335669
# 6             0.036766  0.028595    0.702065  19.095706  0.027098    3.233034
# 7             0.040731  0.028595    0.777778  19.095706  0.027098    4.316713
# 63            0.040731  0.023009    0.776876  19.073573  0.021802    4.299271
# 70            0.036766  0.020485    0.890339  24.216650  0.019639    8.783780
# 71            0.029617  0.020485    0.716387  24.188581  0.019638    3.421500
# 72            0.040731  0.020485    0.844059  20.723028  0.019497    6.151506

# %% [markdown]
# #### Germany with filter

# %%
retail_filtered = df[df['Country']=="Germany"]

# %%
basket4 = (retail_filtered[retail_filtered['Quantity']<10]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets4 = basket4.applymap(encode_units)
basket_sets4.drop('POSTAGE', inplace=True, axis=1)

# %%
frequent_itemsets4 = apriori(basket_sets4, min_support=0.05, use_colnames=True)

# %%
rules4 = association_rules(frequent_itemsets4, metric="lift", min_threshold=1)
rules4
# Out:
#                              antecedents  \
# 0  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 1   (ROUND SNACK BOXES SET OF 4 FRUITS )
#
#                              consequents  antecedent support  \
# 0   (ROUND SNACK BOXES SET OF 4 FRUITS )            0.130435
# 1  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.102975
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.102975  0.057208    0.438596  4.259259  0.043777    1.597826
# 1            0.130435  0.057208    0.555556  4.259259  0.043777    1.956522

# %% [markdown]
# #### For Plotting (not baskte)

# %%
df['Sales']=df['Quantity']*df['UnitPrice']

periods=['year','month','day','dayofweek','dayofyear','weekofyear','quarter']
df=df.join(pd.concat((getattr(df['InvoiceDate'].dt,i).rename(i) for i in periods),axis=1))
df.insert(loc=2,column='year_month',value=df['InvoiceDate'].map(lambda x: 100*x.year + x.month))
df.insert(loc=5,column='hour',value=df.InvoiceDate.dt.hour)

ax=df.groupby('InvoiceNo')['year_month'].unique().value_counts().sort_index().plot(kind='bar',figsize=(15,6))
ax.set_xticklabels(('Dec','Jan','Feb','Mar','Apr','May','Jun','July','Aug','Sep','Oct','Nov','Dec'));
